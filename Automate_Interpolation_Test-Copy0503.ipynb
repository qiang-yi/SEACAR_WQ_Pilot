# %%
import time, math, os, importlib,sys
import sklearn.metrics  
import arcgisscripting
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rasterio as rio
import rasterio.mask
import rasterio.plot as rio_pl
import matplotlib.image as mpimg
from datetime import datetime

from rasterio.plot import show
from rasterio.transform import Affine
from rasterio.mask import mask
from rasterio import MemoryFile
from rasterio.profiles import DefaultGTiffProfile
from scipy.spatial import Voronoi, voronoi_plot_2d
from scipy.stats import sem
from sklearn.metrics import mean_squared_error
from shapely.geometry import box, Polygon, Point
from shapely import wkt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
import contextily as cx

import arcpy
from arcpy.sa import *
import misc.preprocess
import misc.interpolation
arcpy.env.overwriteOutput = True

# %% [markdown]
# # 1. Load and Preprocess Data <a class="anchor" id="load_data"></a>

# %%
# path = "E:/Projects/SEACAR_WQ_Pilot/"
# gis_path = path+'GIS_data/'

path = "D:/Water_Quailty/"
gis_path = path+'GIS_data/'

# %%
# Reload modules in external .py files after editing.
dfAll = pd.read_csv(path + "all_0214.csv").drop(columns=['Unnamed: 0','Unnamed: 0.1','RowID','ValueQualifier'])
# Convert SampleDate froms str to date
dfAll['SampleDate'] = pd.to_datetime(dfAll['SampleDate']).dt.date
# Out:
# C:\Users\xiang11\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\IPython\core\interactiveshell.py:3552: DtypeWarning: Columns (6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
col_ls = ['RowID','ParameterName','ParameterUnits','ProgramLocationID','ActivityType','ManagedAreaName',
                   'SampleDate','Year','Month','ResultValue','ValueQualifier','Latitude_DD','Longitude_DD']
para_ls = ["Salinity","Total Nitrogen","Dissolved Oxygen","Turbidity","Secchi Depth"]
para_ls_ab = ["S","TN","DO","T","SD"]
# Convert full MA names to short names
dictArea    = {'Gasparilla Sound-Charlotte Harbor Aquatic Preserve':'Charlotte Harbor','Big Bend Seagrasses Aquatic Preserve':'Big Bend',
                'Guana Tolomato Matanzas National Estuarine Research Reserve':'GTM Reserve','Estero Bay Aquatic Preserve':'Estero Bay',
                'Biscayne Bay Aquatic Preserve':'Biscayne Bay','Matlacha Pass Aquatic Preserve':'Matlacha Pass AP',
                'Lemon Bay Aquatic Preserve':'Lemon Bay','Cape Haze Aquatic Preserve':'Cape Haze','Pine Island Sound Aquatic Preserve':'Pine Island'}

# Convert full MA names to MA name in ORCP_Managed_Areas_Oct2021
dictArea2    = {'Gasparilla Sound-Charlotte Harbor Aquatic Preserve':'Gasparilla Sound-Charlotte Harbor','Big Bend Seagrasses Aquatic Preserve':'Big Bend Seagrasses',
                'Guana Tolomato Matanzas National Estuarine Research Reserve':'Guana Tolomato Matanzas NERR','Estero Bay Aquatic Preserve':'Estero Bay',
                'Biscayne Bay Aquatic Preserve':'Biscayne Bay','Matlacha Pass Aquatic Preserve':'Matlacha Pass',
                'Lemon Bay Aquatic Preserve':'Lemon Bay','Cape Haze Aquatic Preserve':'Cape Haze','Pine Island Sound Aquatic Preserve':'Pine Island Sound'}
dictArea3    = {'Gasparilla Sound-Charlotte Harbor Aquatic Preserve':'ch','Big Bend Seagrasses Aquatic Preserve':'bb',
                'Guana Tolomato Matanzas National Estuarine Research Reserve':'gtm','Estero Bay Aquatic Preserve':'eb',
                'Biscayne Bay Aquatic Preserve':'bbay','Matlacha Pass Aquatic Preserve':'Matlacha Pass AP',
                'Lemon Bay Aquatic Preserve':'Lemon Bay','Cape Haze Aquatic Preserve':'Cape Haze','Pine Island Sound Aquatic Preserve':'Pine Island'}

dictPara = {"Salinity":'S','Total Nitrogen':'TN','Dissolved Oxygen':'DO','Turbidity':'T','Secchi Depth':'SD'}
dictUnits   = {"Salinity":"ppt","Total Nitrogen": "mg/L","Dissolved Oxygen": "mg/L","Turbidity": "NTU", "Secchi Depth": "m"}
listArea    = dfAll["ManagedAreaName"].unique()
listPara    = ["Salinity","Total Nitrogen","Dissolved Oxygen","Turbidity","Secchi Depth"]
SpatialRef = '3086'

# %% [markdown]
# # 2. Combine Discrete and Continuous Data <a class="anchor" id="combine"></a>
#
# Combine dis and con dataframes

# %%
def interpolation_auto(method,dataframe,managed_area,Year,Season,start_date,end_date,parameter,covariates,out_raster,out_ga_layer,predict_std_err):
    method = method
    dataframe = dataframe
    Area   = managed_area
    Year   = Year
    Season = Season
    start_date,end_date = start_date,end_date
    Para   = parameter
    covariates = covariates
    fname = [dictArea[Area],Year,Season[0:3],dictPara[Para]]
    
    input_pt = gis_path+"input_point/{}/{}{}_{}.shp".format(*fname)
    
    df,gdf= misc.preprocess.select_aggr_area_season(dataframe,start_date,end_date, Area, Para)
    
    try:
        gdf   = gdf.to_crs(int(SpatialRef))
        boundary_shp = gis_path+ 'managed_area_boundary/{}.shp'.format(dictArea[Area][0:3])
        gdf.to_file(input_pt,driver='ESRI Shapefile',crs="EPSG:"+SpatialRef)
        MA = gpd.read_file(gis_path + r"managed_area_boundary/ORCP_Managed_Areas_Oct2021.shp")
        boundary = MA[MA['MA_Name']==dictArea2[Area]].to_crs(int(SpatialRef))
        boundary.to_file(boundary_shp , driver='ESRI Shapefile',crs="EPSG:"+SpatialRef)
        extent = str(boundary.geometry.total_bounds).replace('[','').replace(']','')

        if type(covariates) == str:
            in_explanatory_rasters = gis_path + "covariates/{}/{}.tif".format(covariates, dictArea[Area])
        elif type(covariates) == list:
            in_explanatory_rasters = []
            for i in range(len(covariates)):
                in_explanatory_raster = str(gis_path + "covariates/{}/{}.tif".format(covariates[i], dictArea[Area]))
                in_explanatory_rasters.append(in_explanatory_raster)

        in_features = input_pt
        out_raster = gis_path +"output_raster/{}/{}{}_{}.tif".format(*out_raster)
        value_field = "ResultValu"
        out_ga_layer = gis_path +"ga_layer/{}/{}{}_{}.lyrx".format(*out_ga_layer)
        ga_to_raster = gis_path + 'standard_error_prediction/{}/{}{}_{}.tif'.format(*predict_std_err)
        in_explanatory_rasters = in_explanatory_rasters
        mask = gis_path+ '{}.shp'.format(dictArea3[Area])

        try:
            Result,Stat = misc.interpolation.interpolation(
                            method = method, input_point = in_features, out_raster = out_raster, 
                            z_field = value_field, out_ga_layer = out_ga_layer, extent = extent, 
                            mask = mask, ga_to_raster = ga_to_raster, in_explanatory_rasters = in_explanatory_rasters)
            return out_raster,out_ga_layer,ga_to_raster
        except Exception:
            e = sys.exc_info()[1]
            print(Para + " in " + str(Year) + " " + Season + " caused an error:")
            print(e.args[0])
            return np.nan,np.nan,np.nan    
    except Exception:
            e = sys.exc_info()[1]
            print(Para + " in " + str(Year) + " " + Season + " caused an error:")
            print(e.args[0])
            return np.nan,np.nan,np.nan

# %%
dfSeason = pd.read_csv(path + "OEATUSF_Geospatial_TempSeasons_update_0502.csv")
dfSeason = dfSeason.dropna(subset=["s_start","s_end"]).reset_index(drop=True)

dfSeason['start_date'] = pd.to_datetime(dfSeason['s_start'])
dfSeason["end_date"] = pd.to_datetime(dfSeason["s_end"])
dfSeason["date_range"] = dfSeason["end_date"] - dfSeason["start_date"]
dfSeason["daterange"] = dfSeason.apply(lambda x: int(str(x["date_range"]).split(" ")[0]),axis=1)
dfSeason = dfSeason[dfSeason["daterange"]>0].drop(columns="daterange").reset_index(drop=True)
dfSeason.head()
# Out:
#    Unnamed: 0 param                             ma  st_Year  season  \
# 0         147  temp    Estero Bay Aquatic Preserve     2022  Summer
# 1          71  temp  Biscayne Bay Aquatic Preserve     2022  Summer
# 2          70  temp  Biscayne Bay Aquatic Preserve     2022  Spring
# 3         146  temp    Estero Bay Aquatic Preserve     2022  Spring
# 4          69  temp  Biscayne Bay Aquatic Preserve     2022  Winter
#
#   med_seamo_ma    s_start      s_end             covariates start_date  \
# 0        7-Jun   6/7/2022  8/26/2022  bathymetry+LDI+popden 2022-06-07
# 1        1-Jun   6/1/2022  8/26/2022  bathymetry+LDI+popden 2022-06-01
# 2        2-Mar   3/2/2022  5/31/2022  bathymetry+LDI+popden 2022-03-02
# 3       27-Feb  2/27/2022   6/6/2022  bathymetry+LDI+popden 2022-02-27
# 4        8-Feb   2/8/2022   3/1/2022  bathymetry+LDI+popden 2022-02-08
#
#     end_date date_range
# 0 2022-08-26    80 days
# 1 2022-08-26    86 days
# 2 2022-05-31    90 days
# 3 2022-06-06    99 days
# 4 2022-03-01    21 days

# %%
# Print all managed areas
display(dfSeason['ma'].unique())

# Select the first 3 managed areas
data = dfSeason.assign(**{'Total Nitrogen': np.nan, 'Dissolved Oxygen': np.nan, 'Salinity': np.nan, 'Secchi Depth': np.nan, 'Turbidity': np.nan})
# Out:
# array(['Estero Bay Aquatic Preserve', 'Biscayne Bay Aquatic Preserve',
#        'Guana Tolomato Matanzas National Estuarine Research Reserve',
#        'Gasparilla Sound-Charlotte Harbor Aquatic Preserve',
#        'Big Bend Seagrasses Aquatic Preserve'], dtype=object)

# %%
listPara[3:5]
# Out:
# ['Turbidity', 'Secchi Depth']

# %%
a = dfSeason[(dfSeason['ma'] == 'Estero Bay Aquatic Preserve') & (dfSeason["st_Year"] == 2022)]
a
# Out:
#    Unnamed: 0 param                           ma  st_Year  season  \
# 0         145  temp  Estero Bay Aquatic Preserve     2022  Winter
# 1         147  temp  Estero Bay Aquatic Preserve     2022  Summer
# 4         146  temp  Estero Bay Aquatic Preserve     2022  Spring
#
#   med_seamo_ma     s_start      s_end             covariates
# 0       25-Dec  12/25/2022  2/26/2022  bathymetry+LDI+popden
# 1        7-Jun    6/7/2022  8/26/2022  bathymetry+LDI+popden
# 4       27-Feb   2/27/2022   6/6/2022  bathymetry+LDI+popden

# %%
dfAll[(dfAll['ManagedAreaName'] == 'Biscayne Bay Aquatic Preserve') & (dfAll["Year"] == 2022) & ((dfAll["ParameterName"] == 'Secchi Depth'))]
# Out:
# Empty DataFrame
# Columns: [ParameterName, ParameterUnits, ProgramLocationID, ActivityType, ManagedAreaName, SampleDate, Year, Month, ResultValue, Latitude_DD, Longitude_DD, timestamp]
# Index: []

# %% [markdown]
# Run through the seasonality table

# %%
for i in data.index:
    for para in listPara[3:5]:
        name = [dictArea[data.iloc[i]["ma"]],data.iloc[i]["st_Year"],data.iloc[i]["season"],dictPara[para]]
        print(name)
#         out_raster,out_ga_layer,ga_to_raster = interpolation_auto(method = "rk",
#                            dataframe = dfAll,
#                            managed_area = data.iloc[i]["ma"],
#                            Year = data.iloc[i]["st_Year"],
#                            Season = data.iloc[i]["season"],
#                            start_date = data.iloc[i]["s_start"],
#                            end_date = data.iloc[i]["s_end"],
#                            parameter = para,
#                            covariates = data.iloc[i]["covariates"].split("+"),
#                            out_raster = name,
#                            out_ga_layer = name,
#                            predict_std_err = name)
#         #data.iloc[i]['raster'],data.iloc[i]['GA_layer'],data.iloc[i]['StErrPred'] = out_raster,out_ga_layer,ga_to_raster
#         data.loc[i, para] = out_raster
#         data.to_csv(path + 'output.csv')
#         display('Interpolated row:{}, {}'.format(i,name))
# Out:
# ['Estero Bay', 2022, 'Summer', 'T']
# ['Estero Bay', 2022, 'Summer', 'SD']
# ['Biscayne Bay', 2022, 'Summer', 'T']
# ['Biscayne Bay', 2022, 'Summer', 'SD']
# ['Biscayne Bay', 2022, 'Spring', 'T']
# ['Biscayne Bay', 2022, 'Spring', 'SD']
# ['Estero Bay', 2022, 'Spring', 'T']
# ['Estero Bay', 2022, 'Spring', 'SD']
# ['Biscayne Bay', 2022, 'Winter', 'T']
# ['Biscayne Bay', 2022, 'Winter', 'SD']
# ['Biscayne Bay', 2021, 'Fall', 'T']
# ['Biscayne Bay', 2021, 'Fall', 'SD']
# ['Estero Bay', 2021, 'Fall', 'T']
# ['Estero Bay', 2021, 'Fall', 'SD']
# ['GTM Reserve', 2021, 'Summer', 'T']
# ['GTM Reserve', 2021, 'Summer', 'SD']
# ['Estero Bay', 2021, 'Summer', 'T']
# ['Estero Bay', 2021, 'Summer', 'SD']
# ['Matlacha Pass AP', 2021, 'Summer', 'T']
# ['Matlacha Pass AP', 2021, 'Summer', 'SD']
# ['Biscayne Bay', 2021, 'Summer', 'T']
# ['Biscayne Bay', 2021, 'Summer', 'SD']
# ['Biscayne Bay', 2021, 'Spring', 'T']
# ['Biscayne Bay', 2021, 'Spring', 'SD']
# ['Matlacha Pass AP', 2021, 'Winter', 'T']
# ['Matlacha Pass AP', 2021, 'Winter', 'SD']
# ['Estero Bay', 2021, 'Spring', 'T']
# ['Estero Bay', 2021, 'Spring', 'SD']
# ['GTM Reserve', 2021, 'Spring', 'T']
# ['GTM Reserve', 2021, 'Spring', 'SD']
# ['GTM Reserve', 2021, 'Winter', 'T']
# ['GTM Reserve', 2021, 'Winter', 'SD']
# ['Biscayne Bay', 2021, 'Winter', 'T']
# ['Biscayne Bay', 2021, 'Winter', 'SD']
# ['Biscayne Bay', 2020, 'Fall', 'T']
# ['Biscayne Bay', 2020, 'Fall', 'SD']
# ['Estero Bay', 2020, 'Fall', 'T']
# ['Estero Bay', 2020, 'Fall', 'SD']
# ['GTM Reserve', 2020, 'Fall', 'T']
# ['GTM Reserve', 2020, 'Fall', 'SD']
# ['Matlacha Pass AP', 2020, 'Fall', 'T']
# ['Matlacha Pass AP', 2020, 'Fall', 'SD']
# ['GTM Reserve', 2020, 'Summer', 'T']
# ['GTM Reserve', 2020, 'Summer', 'SD']
# ['Big Bend', 2020, 'Summer', 'T']
# ['Big Bend', 2020, 'Summer', 'SD']
# ['Estero Bay', 2020, 'Summer', 'T']
# ['Estero Bay', 2020, 'Summer', 'SD']
# ['Matlacha Pass AP', 2020, 'Summer', 'T']
# ['Matlacha Pass AP', 2020, 'Summer', 'SD']
# ['Biscayne Bay', 2020, 'Summer', 'T']
# ['Biscayne Bay', 2020, 'Summer', 'SD']
# ['Biscayne Bay', 2020, 'Spring', 'T']
# ['Biscayne Bay', 2020, 'Spring', 'SD']
# ['Matlacha Pass AP', 2020, 'Spring', 'T']
# ['Matlacha Pass AP', 2020, 'Spring', 'SD']
# ['Estero Bay', 2020, 'Spring', 'T']
# ['Estero Bay', 2020, 'Spring', 'SD']
# ['GTM Reserve', 2020, 'Spring', 'T']
# ['GTM Reserve', 2020, 'Spring', 'SD']
# ['Big Bend', 2020, 'Spring', 'T']
# ['Big Bend', 2020, 'Spring', 'SD']
# ['GTM Reserve', 2020, 'Winter', 'T']
# ['GTM Reserve', 2020, 'Winter', 'SD']
# ['Biscayne Bay', 2020, 'Winter', 'T']
# ['Biscayne Bay', 2020, 'Winter', 'SD']
# ['Big Bend', 2020, 'Winter', 'T']
# ['Big Bend', 2020, 'Winter', 'SD']
# ['Big Bend', 2019, 'Fall', 'T']
# ['Big Bend', 2019, 'Fall', 'SD']
# ['Biscayne Bay', 2019, 'Fall', 'T']
# ['Biscayne Bay', 2019, 'Fall', 'SD']
# ['Estero Bay', 2019, 'Fall', 'T']
# ['Estero Bay', 2019, 'Fall', 'SD']
# ['GTM Reserve', 2019, 'Fall', 'T']
# ['GTM Reserve', 2019, 'Fall', 'SD']
# ['Matlacha Pass AP', 2019, 'Fall', 'T']
# ['Matlacha Pass AP', 2019, 'Fall', 'SD']
# ['GTM Reserve', 2019, 'Summer', 'T']
# ['GTM Reserve', 2019, 'Summer', 'SD']
# ['Big Bend', 2019, 'Summer', 'T']
# ['Big Bend', 2019, 'Summer', 'SD']
# ['Estero Bay', 2019, 'Summer', 'T']
# ['Estero Bay', 2019, 'Summer', 'SD']
# ['Matlacha Pass AP', 2019, 'Summer', 'T']
# ['Matlacha Pass AP', 2019, 'Summer', 'SD']
# ['Biscayne Bay', 2019, 'Summer', 'T']
# ['Biscayne Bay', 2019, 'Summer', 'SD']
# ['Biscayne Bay', 2019, 'Spring', 'T']
# ['Biscayne Bay', 2019, 'Spring', 'SD']
# ['Matlacha Pass AP', 2019, 'Spring', 'T']
# ['Matlacha Pass AP', 2019, 'Spring', 'SD']
# ['Estero Bay', 2019, 'Spring', 'T']
# ['Estero Bay', 2019, 'Spring', 'SD']
# ['GTM Reserve', 2019, 'Spring', 'T']
# ['GTM Reserve', 2019, 'Spring', 'SD']
# ['Big Bend', 2019, 'Spring', 'T']
# ['Big Bend', 2019, 'Spring', 'SD']
# ['GTM Reserve', 2019, 'Winter', 'T']
# ['GTM Reserve', 2019, 'Winter', 'SD']
# ['Biscayne Bay', 2019, 'Winter', 'T']
# ['Biscayne Bay', 2019, 'Winter', 'SD']
# ['Big Bend', 2019, 'Winter', 'T']
# ['Big Bend', 2019, 'Winter', 'SD']
# ['Estero Bay', 2018, 'Fall', 'T']
# ['Estero Bay', 2018, 'Fall', 'SD']
# ['GTM Reserve', 2018, 'Fall', 'T']
# ['GTM Reserve', 2018, 'Fall', 'SD']
# ['Matlacha Pass AP', 2018, 'Fall', 'T']
# ['Matlacha Pass AP', 2018, 'Fall', 'SD']
# ['GTM Reserve', 2018, 'Summer', 'T']
# ['GTM Reserve', 2018, 'Summer', 'SD']
# ['Estero Bay', 2018, 'Summer', 'T']
# ['Estero Bay', 2018, 'Summer', 'SD']
# ['Matlacha Pass AP', 2018, 'Summer', 'T']
# ['Matlacha Pass AP', 2018, 'Summer', 'SD']
# ['Matlacha Pass AP', 2018, 'Spring', 'T']
# ['Matlacha Pass AP', 2018, 'Spring', 'SD']
# ['Estero Bay', 2018, 'Spring', 'T']
# ['Estero Bay', 2018, 'Spring', 'SD']
# ['GTM Reserve', 2018, 'Spring', 'T']
# ['GTM Reserve', 2018, 'Spring', 'SD']
# ['GTM Reserve', 2018, 'Winter', 'T']
# ['GTM Reserve', 2018, 'Winter', 'SD']
# ['Estero Bay', 2017, 'Fall', 'T']
# ['Estero Bay', 2017, 'Fall', 'SD']
# ['GTM Reserve', 2017, 'Fall', 'T']
# ['GTM Reserve', 2017, 'Fall', 'SD']
# ['Matlacha Pass AP', 2017, 'Fall', 'T']
# ['Matlacha Pass AP', 2017, 'Fall', 'SD']
# ['GTM Reserve', 2017, 'Summer', 'T']
# ['GTM Reserve', 2017, 'Summer', 'SD']
# ['Estero Bay', 2017, 'Summer', 'T']
# ['Estero Bay', 2017, 'Summer', 'SD']
# ['Matlacha Pass AP', 2017, 'Summer', 'T']
# ['Matlacha Pass AP', 2017, 'Summer', 'SD']
# ['Matlacha Pass AP', 2017, 'Spring', 'T']
# ['Matlacha Pass AP', 2017, 'Spring', 'SD']
# ['Estero Bay', 2017, 'Spring', 'T']
# ['Estero Bay', 2017, 'Spring', 'SD']
# ['GTM Reserve', 2017, 'Spring', 'T']
# ['GTM Reserve', 2017, 'Spring', 'SD']
# ['GTM Reserve', 2017, 'Winter', 'T']
# ['GTM Reserve', 2017, 'Winter', 'SD']
# ['Estero Bay', 2016, 'Fall', 'T']
# ['Estero Bay', 2016, 'Fall', 'SD']
# ['GTM Reserve', 2016, 'Fall', 'T']
# ['GTM Reserve', 2016, 'Fall', 'SD']
# ['Matlacha Pass AP', 2016, 'Fall', 'T']
# ['Matlacha Pass AP', 2016, 'Fall', 'SD']
# ['GTM Reserve', 2016, 'Summer', 'T']
# ['GTM Reserve', 2016, 'Summer', 'SD']
# ['Estero Bay', 2016, 'Summer', 'T']
# ['Estero Bay', 2016, 'Summer', 'SD']
# ['Matlacha Pass AP', 2016, 'Summer', 'T']
# ['Matlacha Pass AP', 2016, 'Summer', 'SD']
# ['Matlacha Pass AP', 2016, 'Spring', 'T']
# ['Matlacha Pass AP', 2016, 'Spring', 'SD']
# ['Estero Bay', 2016, 'Spring', 'T']
# ['Estero Bay', 2016, 'Spring', 'SD']
# ['GTM Reserve', 2016, 'Spring', 'T']
# ['GTM Reserve', 2016, 'Spring', 'SD']
# ['GTM Reserve', 2016, 'Winter', 'T']
# ['GTM Reserve', 2016, 'Winter', 'SD']
# ['Big Bend', 2015, 'Fall', 'T']
# ['Big Bend', 2015, 'Fall', 'SD']
# ['Estero Bay', 2015, 'Fall', 'T']
# ['Estero Bay', 2015, 'Fall', 'SD']
# ['GTM Reserve', 2015, 'Fall', 'T']
# ['GTM Reserve', 2015, 'Fall', 'SD']
# ['Matlacha Pass AP', 2015, 'Fall', 'T']
# ['Matlacha Pass AP', 2015, 'Fall', 'SD']
# ['GTM Reserve', 2015, 'Summer', 'T']
# ['GTM Reserve', 2015, 'Summer', 'SD']
# ['Big Bend', 2015, 'Summer', 'T']
# ['Big Bend', 2015, 'Summer', 'SD']
# ['Estero Bay', 2015, 'Summer', 'T']
# ['Estero Bay', 2015, 'Summer', 'SD']
# ['Matlacha Pass AP', 2015, 'Summer', 'T']
# ['Matlacha Pass AP', 2015, 'Summer', 'SD']
# ['Matlacha Pass AP', 2015, 'Spring', 'T']
# ['Matlacha Pass AP', 2015, 'Spring', 'SD']
# ['Estero Bay', 2015, 'Spring', 'T']
# ['Estero Bay', 2015, 'Spring', 'SD']
# ['GTM Reserve', 2015, 'Spring', 'T']
# ['GTM Reserve', 2015, 'Spring', 'SD']
# ['Big Bend', 2015, 'Spring', 'T']
# ['Big Bend', 2015, 'Spring', 'SD']
# ['GTM Reserve', 2015, 'Winter', 'T']
# ['GTM Reserve', 2015, 'Winter', 'SD']
# ['Big Bend', 2015, 'Winter', 'T']
# ['Big Bend', 2015, 'Winter', 'SD']
# ['Big Bend', 2014, 'Fall', 'T']
# ['Big Bend', 2014, 'Fall', 'SD']
# ['Estero Bay', 2014, 'Fall', 'T']
# ['Estero Bay', 2014, 'Fall', 'SD']
# ['GTM Reserve', 2014, 'Fall', 'T']
# ['GTM Reserve', 2014, 'Fall', 'SD']
# ['Matlacha Pass AP', 2014, 'Fall', 'T']
# ['Matlacha Pass AP', 2014, 'Fall', 'SD']
# ['GTM Reserve', 2014, 'Summer', 'T']
# ['GTM Reserve', 2014, 'Summer', 'SD']
# ['Big Bend', 2014, 'Summer', 'T']
# ['Big Bend', 2014, 'Summer', 'SD']
# ['Estero Bay', 2014, 'Summer', 'T']
# ['Estero Bay', 2014, 'Summer', 'SD']
# ['Matlacha Pass AP', 2014, 'Summer', 'T']
# ['Matlacha Pass AP', 2014, 'Summer', 'SD']
# ['Matlacha Pass AP', 2014, 'Spring', 'T']
# ['Matlacha Pass AP', 2014, 'Spring', 'SD']
# ['Estero Bay', 2014, 'Spring', 'T']
# ['Estero Bay', 2014, 'Spring', 'SD']
# ['GTM Reserve', 2014, 'Spring', 'T']
# ['GTM Reserve', 2014, 'Spring', 'SD']
# ['Big Bend', 2014, 'Spring', 'T']
# ['Big Bend', 2014, 'Spring', 'SD']
# ['GTM Reserve', 2014, 'Winter', 'T']
# ['GTM Reserve', 2014, 'Winter', 'SD']
# ['Big Bend', 2014, 'Winter', 'T']
# ['Big Bend', 2014, 'Winter', 'SD']
# ['Big Bend', 2013, 'Fall', 'T']
# ['Big Bend', 2013, 'Fall', 'SD']
# ['Estero Bay', 2013, 'Fall', 'T']
# ['Estero Bay', 2013, 'Fall', 'SD']
# ['GTM Reserve', 2013, 'Fall', 'T']
# ['GTM Reserve', 2013, 'Fall', 'SD']
# ['Matlacha Pass AP', 2013, 'Fall', 'T']
# ['Matlacha Pass AP', 2013, 'Fall', 'SD']
# ['GTM Reserve', 2013, 'Summer', 'T']
# ['GTM Reserve', 2013, 'Summer', 'SD']
# ['Big Bend', 2013, 'Summer', 'T']
# ['Big Bend', 2013, 'Summer', 'SD']
# ['Estero Bay', 2013, 'Summer', 'T']
# ['Estero Bay', 2013, 'Summer', 'SD']
# ['Matlacha Pass AP', 2013, 'Summer', 'T']
# ['Matlacha Pass AP', 2013, 'Summer', 'SD']
# ['Matlacha Pass AP', 2013, 'Spring', 'T']
# ['Matlacha Pass AP', 2013, 'Spring', 'SD']
# ['Estero Bay', 2013, 'Spring', 'T']
# ['Estero Bay', 2013, 'Spring', 'SD']
# ['GTM Reserve', 2013, 'Spring', 'T']
# ['GTM Reserve', 2013, 'Spring', 'SD']
# ['Big Bend', 2013, 'Spring', 'T']
# ['Big Bend', 2013, 'Spring', 'SD']
# ['GTM Reserve', 2013, 'Winter', 'T']
# ['GTM Reserve', 2013, 'Winter', 'SD']
# ['Big Bend', 2013, 'Winter', 'T']
# ['Big Bend', 2013, 'Winter', 'SD']
# ['Big Bend', 2012, 'Fall', 'T']
# ['Big Bend', 2012, 'Fall', 'SD']
# ['Estero Bay', 2012, 'Fall', 'T']
# ['Estero Bay', 2012, 'Fall', 'SD']
# ['GTM Reserve', 2012, 'Fall', 'T']
# ['GTM Reserve', 2012, 'Fall', 'SD']
# ['Matlacha Pass AP', 2012, 'Fall', 'T']
# ['Matlacha Pass AP', 2012, 'Fall', 'SD']
# ['GTM Reserve', 2012, 'Summer', 'T']
# ['GTM Reserve', 2012, 'Summer', 'SD']
# ['Big Bend', 2012, 'Summer', 'T']
# ['Big Bend', 2012, 'Summer', 'SD']
# ['Estero Bay', 2012, 'Summer', 'T']
# ['Estero Bay', 2012, 'Summer', 'SD']
# ['Matlacha Pass AP', 2012, 'Summer', 'T']
# ['Matlacha Pass AP', 2012, 'Summer', 'SD']
# ['Matlacha Pass AP', 2012, 'Spring', 'T']
# ['Matlacha Pass AP', 2012, 'Spring', 'SD']
# ['Estero Bay', 2012, 'Spring', 'T']
# ['Estero Bay', 2012, 'Spring', 'SD']
# ['GTM Reserve', 2012, 'Spring', 'T']
# ['GTM Reserve', 2012, 'Spring', 'SD']
# ['Big Bend', 2012, 'Spring', 'T']
# ['Big Bend', 2012, 'Spring', 'SD']
# ['GTM Reserve', 2012, 'Winter', 'T']
# ['GTM Reserve', 2012, 'Winter', 'SD']
# ['Big Bend', 2012, 'Winter', 'T']
# ['Big Bend', 2012, 'Winter', 'SD']
# ['Big Bend', 2011, 'Fall', 'T']
# ['Big Bend', 2011, 'Fall', 'SD']
# ['Estero Bay', 2011, 'Fall', 'T']
# ['Estero Bay', 2011, 'Fall', 'SD']
# ['GTM Reserve', 2011, 'Fall', 'T']
# ['GTM Reserve', 2011, 'Fall', 'SD']
# ['Matlacha Pass AP', 2011, 'Fall', 'T']
# ['Matlacha Pass AP', 2011, 'Fall', 'SD']
# ['GTM Reserve', 2011, 'Summer', 'T']
# ['GTM Reserve', 2011, 'Summer', 'SD']
# ['Big Bend', 2011, 'Summer', 'T']
# ['Big Bend', 2011, 'Summer', 'SD']
# ['Estero Bay', 2011, 'Summer', 'T']
# ['Estero Bay', 2011, 'Summer', 'SD']
# ['Matlacha Pass AP', 2011, 'Summer', 'T']
# ['Matlacha Pass AP', 2011, 'Summer', 'SD']
# ['Matlacha Pass AP', 2011, 'Spring', 'T']
# ['Matlacha Pass AP', 2011, 'Spring', 'SD']
# ['Estero Bay', 2011, 'Spring', 'T']
# ['Estero Bay', 2011, 'Spring', 'SD']
# ['GTM Reserve', 2011, 'Spring', 'T']
# ['GTM Reserve', 2011, 'Spring', 'SD']
# ['Big Bend', 2011, 'Spring', 'T']
# ['Big Bend', 2011, 'Spring', 'SD']
# ['GTM Reserve', 2011, 'Winter', 'T']
# ['GTM Reserve', 2011, 'Winter', 'SD']
# ['Big Bend', 2011, 'Winter', 'T']
# ['Big Bend', 2011, 'Winter', 'SD']
# ['Big Bend', 2010, 'Fall', 'T']
# ['Big Bend', 2010, 'Fall', 'SD']
# ['Estero Bay', 2010, 'Fall', 'T']
# ['Estero Bay', 2010, 'Fall', 'SD']
# ['GTM Reserve', 2010, 'Fall', 'T']
# ['GTM Reserve', 2010, 'Fall', 'SD']
# ['Matlacha Pass AP', 2010, 'Fall', 'T']
# ['Matlacha Pass AP', 2010, 'Fall', 'SD']
# ['GTM Reserve', 2010, 'Summer', 'T']
# ['GTM Reserve', 2010, 'Summer', 'SD']
# ['Big Bend', 2010, 'Summer', 'T']
# ['Big Bend', 2010, 'Summer', 'SD']
# ['Estero Bay', 2010, 'Summer', 'T']
# ['Estero Bay', 2010, 'Summer', 'SD']
# ['Matlacha Pass AP', 2010, 'Summer', 'T']
# ['Matlacha Pass AP', 2010, 'Summer', 'SD']
# ['Matlacha Pass AP', 2010, 'Spring', 'T']
# ['Matlacha Pass AP', 2010, 'Spring', 'SD']
# ['Estero Bay', 2010, 'Spring', 'T']
# ['Estero Bay', 2010, 'Spring', 'SD']
# ['GTM Reserve', 2010, 'Spring', 'T']
# ['GTM Reserve', 2010, 'Spring', 'SD']
# ['Big Bend', 2010, 'Spring', 'T']
# ['Big Bend', 2010, 'Spring', 'SD']
# ['GTM Reserve', 2010, 'Winter', 'T']
# ['GTM Reserve', 2010, 'Winter', 'SD']
# ['Big Bend', 2010, 'Winter', 'T']
# ['Big Bend', 2010, 'Winter', 'SD']
# ['Big Bend', 2009, 'Fall', 'T']
# ['Big Bend', 2009, 'Fall', 'SD']
# ['Estero Bay', 2009, 'Fall', 'T']
# ['Estero Bay', 2009, 'Fall', 'SD']
# ['GTM Reserve', 2009, 'Fall', 'T']
# ['GTM Reserve', 2009, 'Fall', 'SD']
# ['Matlacha Pass AP', 2009, 'Fall', 'T']
# ['Matlacha Pass AP', 2009, 'Fall', 'SD']
# ['GTM Reserve', 2009, 'Summer', 'T']
# ['GTM Reserve', 2009, 'Summer', 'SD']
# ['Big Bend', 2009, 'Summer', 'T']
# ['Big Bend', 2009, 'Summer', 'SD']
# ['Estero Bay', 2009, 'Summer', 'T']
# ['Estero Bay', 2009, 'Summer', 'SD']
# ['Matlacha Pass AP', 2009, 'Summer', 'T']
# ['Matlacha Pass AP', 2009, 'Summer', 'SD']
# ['Matlacha Pass AP', 2009, 'Spring', 'T']
# ['Matlacha Pass AP', 2009, 'Spring', 'SD']
# ['Estero Bay', 2009, 'Spring', 'T']
# ['Estero Bay', 2009, 'Spring', 'SD']
# ['GTM Reserve', 2009, 'Spring', 'T']
# ['GTM Reserve', 2009, 'Spring', 'SD']
# ['Big Bend', 2009, 'Spring', 'T']
# ['Big Bend', 2009, 'Spring', 'SD']
# ['GTM Reserve', 2009, 'Winter', 'T']
# ['GTM Reserve', 2009, 'Winter', 'SD']
# ['Big Bend', 2009, 'Winter', 'T']
# ['Big Bend', 2009, 'Winter', 'SD']
# ['Big Bend', 2008, 'Fall', 'T']
# ['Big Bend', 2008, 'Fall', 'SD']
# ['Estero Bay', 2008, 'Fall', 'T']
# ['Estero Bay', 2008, 'Fall', 'SD']
# ['GTM Reserve', 2008, 'Fall', 'T']
# ['GTM Reserve', 2008, 'Fall', 'SD']
# ['Matlacha Pass AP', 2008, 'Fall', 'T']
# ['Matlacha Pass AP', 2008, 'Fall', 'SD']
# ['GTM Reserve', 2008, 'Summer', 'T']
# ['GTM Reserve', 2008, 'Summer', 'SD']
# ['Big Bend', 2008, 'Summer', 'T']
# ['Big Bend', 2008, 'Summer', 'SD']
# ['Estero Bay', 2008, 'Summer', 'T']
# ['Estero Bay', 2008, 'Summer', 'SD']
# ['Matlacha Pass AP', 2008, 'Summer', 'T']
# ['Matlacha Pass AP', 2008, 'Summer', 'SD']
# ['Matlacha Pass AP', 2008, 'Spring', 'T']
# ['Matlacha Pass AP', 2008, 'Spring', 'SD']
# ['Estero Bay', 2008, 'Spring', 'T']
# ['Estero Bay', 2008, 'Spring', 'SD']
# ['GTM Reserve', 2008, 'Spring', 'T']
# ['GTM Reserve', 2008, 'Spring', 'SD']
# ['Big Bend', 2008, 'Spring', 'T']
# ['Big Bend', 2008, 'Spring', 'SD']
# ['GTM Reserve', 2008, 'Winter', 'T']
# ['GTM Reserve', 2008, 'Winter', 'SD']
# ['Big Bend', 2008, 'Winter', 'T']
# ['Big Bend', 2008, 'Winter', 'SD']
# ['Big Bend', 2007, 'Fall', 'T']
# ['Big Bend', 2007, 'Fall', 'SD']
# ['Estero Bay', 2007, 'Fall', 'T']
# ['Estero Bay', 2007, 'Fall', 'SD']
# ['GTM Reserve', 2007, 'Fall', 'T']
# ['GTM Reserve', 2007, 'Fall', 'SD']
# ['Matlacha Pass AP', 2007, 'Fall', 'T']
# ['Matlacha Pass AP', 2007, 'Fall', 'SD']
# ['GTM Reserve', 2007, 'Summer', 'T']
# ['GTM Reserve', 2007, 'Summer', 'SD']
# ['Big Bend', 2007, 'Summer', 'T']
# ['Big Bend', 2007, 'Summer', 'SD']
# ['Estero Bay', 2007, 'Summer', 'T']
# ['Estero Bay', 2007, 'Summer', 'SD']
# ['Matlacha Pass AP', 2007, 'Summer', 'T']
# ['Matlacha Pass AP', 2007, 'Summer', 'SD']
# ['Matlacha Pass AP', 2007, 'Spring', 'T']
# ['Matlacha Pass AP', 2007, 'Spring', 'SD']
# ['Estero Bay', 2007, 'Spring', 'T']
# ['Estero Bay', 2007, 'Spring', 'SD']
# ['GTM Reserve', 2007, 'Spring', 'T']
# ['GTM Reserve', 2007, 'Spring', 'SD']
# ['Big Bend', 2007, 'Spring', 'T']
# ['Big Bend', 2007, 'Spring', 'SD']
# ['GTM Reserve', 2007, 'Winter', 'T']
# ['GTM Reserve', 2007, 'Winter', 'SD']
# ['Big Bend', 2007, 'Winter', 'T']
# ['Big Bend', 2007, 'Winter', 'SD']
# ['Big Bend', 2006, 'Fall', 'T']
# ['Big Bend', 2006, 'Fall', 'SD']
# ['Estero Bay', 2006, 'Fall', 'T']
# ['Estero Bay', 2006, 'Fall', 'SD']
# ['GTM Reserve', 2006, 'Fall', 'T']
# ['GTM Reserve', 2006, 'Fall', 'SD']
# ['Matlacha Pass AP', 2006, 'Fall', 'T']
# ['Matlacha Pass AP', 2006, 'Fall', 'SD']
# ['GTM Reserve', 2006, 'Summer', 'T']
# ['GTM Reserve', 2006, 'Summer', 'SD']
# ['Big Bend', 2006, 'Summer', 'T']
# ['Big Bend', 2006, 'Summer', 'SD']
# ['Estero Bay', 2006, 'Summer', 'T']
# ['Estero Bay', 2006, 'Summer', 'SD']
# ['Matlacha Pass AP', 2006, 'Summer', 'T']
# ['Matlacha Pass AP', 2006, 'Summer', 'SD']
# ['Matlacha Pass AP', 2006, 'Spring', 'T']
# ['Matlacha Pass AP', 2006, 'Spring', 'SD']
# ['Estero Bay', 2006, 'Spring', 'T']
# ['Estero Bay', 2006, 'Spring', 'SD']
# ['GTM Reserve', 2006, 'Spring', 'T']
# ['GTM Reserve', 2006, 'Spring', 'SD']
# ['Big Bend', 2006, 'Spring', 'T']
# ['Big Bend', 2006, 'Spring', 'SD']
# ['GTM Reserve', 2006, 'Winter', 'T']
# ['GTM Reserve', 2006, 'Winter', 'SD']
# ['Big Bend', 2006, 'Winter', 'T']
# ['Big Bend', 2006, 'Winter', 'SD']
# ['Big Bend', 2005, 'Fall', 'T']
# ['Big Bend', 2005, 'Fall', 'SD']
# ['Estero Bay', 2005, 'Fall', 'T']
# ['Estero Bay', 2005, 'Fall', 'SD']
# ['GTM Reserve', 2005, 'Fall', 'T']
# ['GTM Reserve', 2005, 'Fall', 'SD']
# ['Matlacha Pass AP', 2005, 'Fall', 'T']
# ['Matlacha Pass AP', 2005, 'Fall', 'SD']
# ['GTM Reserve', 2005, 'Summer', 'T']
# ['GTM Reserve', 2005, 'Summer', 'SD']
# ['Big Bend', 2005, 'Summer', 'T']
# ['Big Bend', 2005, 'Summer', 'SD']
# ['Estero Bay', 2005, 'Summer', 'T']
# ['Estero Bay', 2005, 'Summer', 'SD']
# ['Matlacha Pass AP', 2005, 'Summer', 'T']
# ['Matlacha Pass AP', 2005, 'Summer', 'SD']
# ['Matlacha Pass AP', 2005, 'Spring', 'T']
# ['Matlacha Pass AP', 2005, 'Spring', 'SD']
# ['Estero Bay', 2005, 'Spring', 'T']
# ['Estero Bay', 2005, 'Spring', 'SD']
# ['GTM Reserve', 2005, 'Spring', 'T']
# ['GTM Reserve', 2005, 'Spring', 'SD']
# ['Big Bend', 2005, 'Spring', 'T']
# ['Big Bend', 2005, 'Spring', 'SD']
# ['GTM Reserve', 2005, 'Winter', 'T']
# ['GTM Reserve', 2005, 'Winter', 'SD']
# ['Big Bend', 2005, 'Winter', 'T']
# ['Big Bend', 2005, 'Winter', 'SD']
# ['Big Bend', 2004, 'Fall', 'T']
# ['Big Bend', 2004, 'Fall', 'SD']
# ['Estero Bay', 2004, 'Fall', 'T']
# ['Estero Bay', 2004, 'Fall', 'SD']
# ['GTM Reserve', 2004, 'Fall', 'T']
# ['GTM Reserve', 2004, 'Fall', 'SD']
# ['GTM Reserve', 2004, 'Summer', 'T']
# ['GTM Reserve', 2004, 'Summer', 'SD']
# ['Big Bend', 2004, 'Summer', 'T']
# ['Big Bend', 2004, 'Summer', 'SD']
# ['Estero Bay', 2004, 'Summer', 'T']
# ['Estero Bay', 2004, 'Summer', 'SD']
# ['Estero Bay', 2004, 'Winter', 'T']
# ['Estero Bay', 2004, 'Winter', 'SD']
# ['GTM Reserve', 2004, 'Spring', 'T']
# ['GTM Reserve', 2004, 'Spring', 'SD']
# ['Big Bend', 2004, 'Spring', 'T']
# ['Big Bend', 2004, 'Spring', 'SD']
# ['GTM Reserve', 2004, 'Winter', 'T']
# ['GTM Reserve', 2004, 'Winter', 'SD']
# ['Big Bend', 2004, 'Winter', 'T']
# ['Big Bend', 2004, 'Winter', 'SD']
# ['GTM Reserve', 2003, 'Fall', 'T']
# ['GTM Reserve', 2003, 'Fall', 'SD']
# ['GTM Reserve', 2003, 'Summer', 'T']
# ['GTM Reserve', 2003, 'Summer', 'SD']
# ['GTM Reserve', 2003, 'Spring', 'T']
# ['GTM Reserve', 2003, 'Spring', 'SD']
# ['GTM Reserve', 2003, 'Winter', 'T']
# ['GTM Reserve', 2003, 'Winter', 'SD']
# ['GTM Reserve', 2002, 'Fall', 'T']
# ['GTM Reserve', 2002, 'Fall', 'SD']
# ['GTM Reserve', 2002, 'Summer', 'T']
# ['GTM Reserve', 2002, 'Summer', 'SD']
# ['GTM Reserve', 2002, 'Spring', 'T']
# ['GTM Reserve', 2002, 'Spring', 'SD']
# ['GTM Reserve', 2002, 'Winter', 'T']
# ['GTM Reserve', 2002, 'Winter', 'SD']
# ['GTM Reserve', 2001, 'Fall', 'T']
# ['GTM Reserve', 2001, 'Fall', 'SD']
# ['GTM Reserve', 2001, 'Summer', 'T']
# ['GTM Reserve', 2001, 'Summer', 'SD']
# ['GTM Reserve', 2001, 'Spring', 'T']
# ['GTM Reserve', 2001, 'Spring', 'SD']
# ['GTM Reserve', 2001, 'Winter', 'T']
# ['GTM Reserve', 2001, 'Winter', 'SD']

# %%
for i in data.index:
    for para in listPara[3:5]:
        name = [dictArea[data.iloc[i]["ma"]],data.iloc[i]["st_Year"],data.iloc[i]["season"],dictPara[para]]
        out_raster,out_ga_layer,ga_to_raster = interpolation_auto(method = "rk",
                           dataframe = dfAll,
                           managed_area = data.iloc[i]["ma"],
                           Year = data.iloc[i]["st_Year"],
                           Season = data.iloc[i]["season"],
                           start_date = data.iloc[i]["s_start"],
                           end_date = data.iloc[i]["s_end"],
                           parameter = para,
                           covariates = data.iloc[i]["covariates"].split("+"),
                           out_raster = name,
                           out_ga_layer = name,
                           predict_std_err = name)
        #data.iloc[i]['raster'],data.iloc[i]['GA_layer'],data.iloc[i]['StErrPred'] = out_raster,out_ga_layer,ga_to_raster
        data.loc[i, para] = out_raster
        data.to_csv(path + 'output.csv')
        display('Interpolated row:{}, {}'.format(i,name))
# Out:
# C:\Users\xiang11\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# Start the interpolation with the RK method
# --- Time lapse: 59.78075098991394 seconds ---
# "Interpolated row:0, ['Estero Bay', 2022, 'Summer', 'T']"
# Start the interpolation with the RK method
# Secchi Depth in 2022 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
# "Interpolated row:0, ['Estero Bay', 2022, 'Summer', 'SD']"
# Start the interpolation with the RK method
# Turbidity in 2022 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
# "Interpolated row:1, ['Biscayne Bay', 2022, 'Summer', 'T']"
# Secchi Depth in 2022 Summer caused an error:
# Cannot write empty DataFrame to file.
# "Interpolated row:1, ['Biscayne Bay', 2022, 'Summer', 'SD']"
# Start the interpolation with the RK method
# --- Time lapse: 187.71939373016357 seconds ---
# "Interpolated row:2, ['Biscayne Bay', 2022, 'Spring', 'T']"
# Secchi Depth in 2022 Spring caused an error:
# Cannot write empty DataFrame to file.
# "Interpolated row:2, ['Biscayne Bay', 2022, 'Spring', 'SD']"
# Start the interpolation with the RK method
# --- Time lapse: 69.75648975372314 seconds ---
# "Interpolated row:3, ['Estero Bay', 2022, 'Spring', 'T']"
# Start the interpolation with the RK method
# Secchi Depth in 2022 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
# "Interpolated row:3, ['Estero Bay', 2022, 'Spring', 'SD']"
# Start the interpolation with the RK method
